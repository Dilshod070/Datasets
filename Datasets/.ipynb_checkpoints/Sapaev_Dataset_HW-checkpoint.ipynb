# %%
import pandas as pd 
import datetime
import numpy as np 
import matplotlib.pyplot as plt 
import statsmodels.api as sm
from pylab import rcParams

# %matplotlib inline

# %%
filename = 'venezia.csv'

# %%
data = pd.read_csv(filename)

# %%
data.reset_index(inplace=True)
data['datetime'] = pd.to_datetime(data['datetime'])
data = data.set_index('datetime')

# %%
# Стандартно, чтобы понять о чем вообще этот датасет
# Датасет хранит данные по уровню воды в Венеции относительно какой-то стандартной точки
# Кажая запись - это один час, начиная с 1-января-1983 01:00:00 по 1-января-2016 00:00:00
# Всегдо 289272 часа => 12053 дня => 34 года (почти)
print('head:\n', data.head(3))
print('\ntail:\n', data.tail(1))
print('\ndescribe:\n', data.describe().T)
print('\nshape:', data.shape)
# Out:
# head:
#                       index  level
# datetime
# 1983-01-01 01:00:00      0   44.0
# 1983-01-01 02:00:00      1   35.0
# 1983-01-01 03:00:00      2   23.0
#
# tail:
#               index  level
# datetime
# 2016-01-01  289271   20.0
#
# describe:
#            count           mean           std   min       25%       50%  \
# index  289272.0  144635.500000  83505.777872   0.0  72317.75  144635.5
# level  289272.0      25.883449     29.130133 -92.0      6.00      27.0
#
#              75%       max
# index  216953.25  289271.0
# level      47.00     159.0
#
# shape: (289272, 2)

# %%
# datetimes = pd.to_datetime(data.datetime)
levels = data.level
train = data.sort_values('datetime', ascending = True)

# %%
# Данных слишком много, чтобы можно было сделать какие-либо выводы
data.level.plot(figsize=(15,6))

# %%
# Выведем последние 10 дней : 240 часов
# Хорошо видно наличие сезонности (причем с периодом ровно 24 часа!)
# Более того, можно подумать и преположить что эта сезонность как-то связана с приливами и отливами
# Чуть позже мы это попытаемся проверить, а пока попробум лучше изучить датасет
data.level[-240:].plot(figsize=(15,6))

# %%
# Посмотрим на STL-декомпозицию ряда
# Да уж, по такой декомпозиции ничего особо не скажешь, поэтому дальше я буду брать какой-то
# небольшой кусок с конца ряда
rcParams['figure.figsize'] = 32, 8
sm.tsa.seasonal_decompose(data.level, freq=24).plot()
plt.show()

# %%
# Посмотрим на STL-декомпозицию ряда за последние 50 дней
# Здесь уже более интерпретируемый результат
# Алгорит потвердил мои наблюдения о налии сезонности
# Так же на тренде можно увидеть, что в конце декабря 2015 года вода в среднем поднималась выше,
# чем в остальное время (странно, что она не замерзала зимой)
rcParams['figure.figsize'] = 16, 8
sm.tsa.seasonal_decompose(data.level[-1200:], freq=24).plot()
plt.show()

# %%
# Интересно было бы взять тренд по всем наблюдениям и его так же разложить
# Потому что я почти уверен, что сезнность есть не только по дням, но и по Годам!
